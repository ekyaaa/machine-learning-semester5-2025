# %% [markdown]
# <a href="https://colab.research.google.com/github/ekyaaa/machine-learning-semester5-2025/blob/main/TG3_2341720111_Ekya_Muhammad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Tugas**
# Wisconsin Breast Cancer <br>
# Berhubung pada praktikum sudah ada source codenya maka saya akan langsung mengerjakan bagian tugas.🙏

# %%
# !pip install -q pandas matplotlib numpy

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns # Import seaborn for enhanced visualization
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dpath = '/content/drive/MyDrive/ML_Dataset/tg3/wbc.csv'
df = pd.read_csv(dpath)

# 1. Pisahkan antara variabel yang dapat digunakan dan variabel yang tidak dapat digunakan.
df_clean = df.drop(['id', 'Unnamed: 32'], axis=1, errors='ignore')
df_clean.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
# 2. Lakukan proses encoding pada kolom "diagnosis".
df['diagnosis'].head()
df['diagnosis'].describe()


le = LabelEncoder()
df['diagnosis'] = le.fit_transform(df['diagnosis'])
df.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df['diagnosis'].describe()
# Out:
# count    569.000000
# mean       0.372583
# std        0.483918
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: diagnosis, dtype: float64

# %%
# 3. Lakukan proses standardisasi pada semua kolom yang memiliki nilai numerik.

# Gunakan dataframe yang sudah dibersihkan
df_clean = df.drop(['id', 'Unnamed: 32'], axis=1, errors='ignore')

# Pisahkan target dan fitur
y = df_clean['diagnosis']
X = df_clean.drop('diagnosis', axis=1)

# Ambil hanya kolom numerik
numeric_cols = X.select_dtypes(include=["number"]).columns

constant_cols = [col for col in numeric_cols if X[col].std() == 0]
print("Kolom konstan:", constant_cols)

X = X.drop(columns=constant_cols)

# Standardisasi
scaler = StandardScaler()
X[numeric_cols] = scaler.fit_transform(X[numeric_cols])

# Gabungkan kembali dengan target
df_scaled = pd.concat([y, X], axis=1)

df_scaled.head()
# Out:
# Kolom konstan: []
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1     1.097064     -2.073335        1.269934   0.984375
# 1          1     1.829821     -0.353632        1.685955   1.908708
# 2          1     1.579888      0.456187        1.566503   1.558884
# 3          1    -0.768909      0.253732       -0.592687  -0.764464
# 4          1     1.750297     -1.151816        1.776573   1.826229
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0         1.568466          3.283515        2.652874             2.532475
# 1        -0.826962         -0.487072       -0.023846             0.548144
# 2         0.942210          1.052926        1.363478             2.037231
# 3         3.283553          3.402909        1.915897             1.451707
# 4         0.280372          0.539340        1.371011             1.428493
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
# 4. Lakukan proses stratified split data untuk membuat data latih dan data uji dengan rasio 80:20.
# Pisahkan fitur dan target
X = df.drop("diagnosis", axis=1)
y = df["diagnosis"]

# Stratified split dengan rasio 80:20
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

print("Jumlah data latih:", X_train.shape[0])
print("Jumlah data uji  :", X_test.shape[0])
print("Distribusi y_train:", y_train.value_counts(normalize=True))
print("Distribusi y_test :", y_test.value_counts(normalize=True))
# Out:
# Jumlah data latih: 455
# Jumlah data uji  : 114
# Distribusi y_train: diagnosis
# 0    0.626374
# 1    0.373626
# Name: proportion, dtype: float64
# Distribusi y_test : diagnosis
# 0    0.631579
# 1    0.368421
# Name: proportion, dtype: float64
